# %% [markdown]
# # Using `ibis` to connect to MIMIC IV on Google BigQuery
#
# Environments in Google Colaboratory are not persistent. If we use any software that is not part of teh Google Python Colaboratory environment, we must install it during each session.
#
# We are going to be using Ibis, so this must be installed.

# %%
# !pip install ibis-framework[bigquery]

# %%
import ibis
from google_auth_oauthlib import flow
import os

# %% [markdown]
# ### Authenticate using `google.colab`

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')

# %% [markdown]
# ## This is copied straight from the Google documentation.
#
# If you haven't verified the app with Google you get some security warnings you need to click through.

# %%
# TODO: Uncomment the line below to set the `launch_browser` variable.
launch_browser = True
#
# The `launch_browser` boolean variable indicates if a local server is used
# as the callback URL in the auth flow. A value of `True` is recommended,
# but a local server does not work if accessing the application remotely,
# such as over SSH or from a remote Jupyter notebook.

appflow = flow.InstalledAppFlow.from_client_secrets_file(
    secret, scopes=["https://www.googleapis.com/auth/bigquery"]
)

if launch_browser:
    appflow.run_local_server()
else:
    appflow.run_console()

credentials = appflow.credentials
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=351306700747-5t1ni8s29h7mug06vls19q52pbma4f8e.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fbigquery&state=kJe2M31F9LoWG1JZVokDk4RMjuXHXh&access_type=offline

# %% [markdown]
# ### Pass the credentials to the `ibis` `connect` function.

# %%
conn = ibis.bigquery.connect(
    project_id="mimic4-bq",
    dataset_id='physionet-data.mimic_core')

# %% [markdown]
# ### Once we connect we can list all the databases we have access to

# %%
conn.list_databases()
# Out:
# ['eicu_crd_demo',
#  'mimic_core',
#  'mimic_derived',
#  'mimic_hosp',
#  'mimic_icu',
#  'mimiciii_clinical',
#  'mimiciii_demo',
#  'mimiciii_derived',
#  'mimiciii_notes']

# %% [markdown]
# ### Since I connected to `mimic_core`, I can list the tables in this database

# %%
conn.list_tables()
# Out:
# ['admissions', 'patients', 'transfers']

# %%
patients = conn.table("patients")

# %%
patients.schema()
# Out:
# ibis.Schema {
#   subject_id         int64
#   gender             string
#   anchor_age         int64
#   anchor_year        int64
#   anchor_year_group  string
#   dod                date
# }

# %% [markdown]
# ### And do queries

# %%
patients.execute(limit=20)
# Out:
#     subject_id gender  anchor_age  anchor_year anchor_year_group dod
# 0     10137012      F           0         2110       2008 - 2010 NaT
# 1     10156260      M           0         2110       2014 - 2016 NaT
# 2     10158897      M           0         2110       2008 - 2010 NaT
# 3     10413283      M           0         2110       2014 - 2016 NaT
# 4     10660064      M           0         2110       2017 - 2019 NaT
# 5     10736768      F           0         2110       2017 - 2019 NaT
# 6     10782862      F           0         2110       2008 - 2010 NaT
# 7     10942655      M           0         2110       2008 - 2010 NaT
# 8     10999598      M           0         2110       2008 - 2010 NaT
# 9     11024137      F           0         2110       2008 - 2010 NaT
# 10    11150953      M           0         2110       2017 - 2019 NaT
# 11    11384055      M           0         2110       2011 - 2013 NaT
# 12    11516471      F           0         2110       2017 - 2019 NaT
# 13    11624865      F           0         2110       2011 - 2013 NaT
# 14    11762645      F           0         2110       2017 - 2019 NaT
# 15    11833026      M           0         2110       2014 - 2016 NaT
# 16    11931679      F           0         2110       2011 - 2013 NaT
# 17    12401393      F           0         2110       2008 - 2010 NaT
# 18    12416807      F           0         2110       2011 - 2013 NaT
# 19    12419506      F           0         2110       2008 - 2010 NaT

# %%
conn.table("admissions").execute(limit=20)
# Out:
#     subject_id   hadm_id           admittime           dischtime  \
# 0     12427812  21593330 2184-01-06 11:51:00 2184-01-10 11:45:00
# 1     14029832  22059088 2120-01-18 01:28:00 2120-01-20 16:13:00
# 2     12897089  21776699 2149-02-25 01:40:00 2149-02-27 14:05:00
# 3     16050270  23791681 2161-07-01 21:13:00 2161-07-05 15:45:00
# 4     14068957  26940015 2130-04-07 10:00:00 2130-04-10 18:44:00
# 5     12501437  22620680 2188-09-08 19:35:00 2188-09-11 14:00:00
# 6     13466375  21011631 2149-08-30 04:30:00 2149-09-29 18:29:00
# 7     10734403  26588273 2110-06-20 14:45:00 2110-06-24 18:15:00
# 8     12537266  27845175 2111-09-04 03:52:00 2111-09-16 16:14:00
# 9     10368348  21406513 2160-06-01 03:50:00 2160-06-03 12:00:00
# 10    16738906  26542901 2150-01-23 20:12:00 2150-01-29 14:00:00
# 11    12031095  25636155 2162-04-06 00:38:00 2162-04-30 12:10:00
# 12    13274858  22601045 2152-12-11 12:33:00 2152-12-18 19:30:00
# 13    19940860  24902106 2130-12-31 09:19:00 2131-01-22 13:33:00
# 14    18186739  29454835 2121-07-28 15:25:00 2121-08-23 16:26:00
# 15    18863892  26824106 2181-10-21 01:06:00 2181-10-24 12:30:00
# 16    17727602  24085356 2139-09-25 16:08:00 2139-09-30 12:00:00
# 17    17615674  27014468 2142-11-29 21:16:00 2143-01-13 12:28:00
# 18    11786836  29132076 2117-05-04 19:28:00 2117-08-17 17:28:00
# 19    19858751  23670116 2164-08-24 03:26:00 2164-09-05 12:10:00
#
#              deathtime admission_type      admission_location  \
# 0                  NaT         URGENT      PHYSICIAN REFERRAL
# 1                  NaT         URGENT  TRANSFER FROM HOSPITAL
# 2                  NaT         URGENT      PHYSICIAN REFERRAL
# 3                  NaT         URGENT          PROCEDURE SITE
# 4                  NaT         URGENT  TRANSFER FROM HOSPITAL
# 5                  NaT         URGENT  TRANSFER FROM HOSPITAL
# 6                  NaT         URGENT  TRANSFER FROM HOSPITAL
# 7  2110-06-24 18:15:00         URGENT  TRANSFER FROM HOSPITAL
# 8                  NaT         URGENT  TRANSFER FROM HOSPITAL
# 9                  NaT         URGENT      PHYSICIAN REFERRAL
# 10                 NaT         URGENT  TRANSFER FROM HOSPITAL
# 11                 NaT         URGENT  TRANSFER FROM HOSPITAL
# 12                 NaT         URGENT  TRANSFER FROM HOSPITAL
# 13                 NaT         URGENT                    None
# 14                 NaT         URGENT                    None
# 15                 NaT         URGENT                    None
# 16                 NaT         URGENT                    None
# 17                 NaT         URGENT                    None
# 18                 NaT         URGENT                    None
# 19                 NaT         URGENT                    None
#
#    discharge_location insurance language marital_status  \
# 0                HOME     Other  ENGLISH           None
# 1                HOME     Other  ENGLISH           None
# 2                HOME     Other  ENGLISH           None
# 3                HOME     Other  ENGLISH           None
# 4                HOME     Other  ENGLISH           None
# 5                HOME     Other  ENGLISH           None
# 6      ACUTE HOSPITAL  Medicare  ENGLISH           None
# 7                None     Other  ENGLISH           None
# 8                HOME     Other  ENGLISH           None
# 9                HOME  Medicaid  ENGLISH           None
# 10              REHAB  Medicare  ENGLISH           None
# 11   HOME HEALTH CARE     Other        ?           None
# 12              REHAB  Medicare  ENGLISH           None
# 13   HOME HEALTH CARE     Other  ENGLISH           None
# 14               HOME     Other  ENGLISH           None
# 15               HOME     Other  ENGLISH           None
# 16               HOME     Other  ENGLISH           None
# 17               HOME  Medicaid  ENGLISH           None
# 18   HOME HEALTH CARE     Other  ENGLISH           None
# 19   HOME HEALTH CARE     Other  ENGLISH           None
#
#                  ethnicity edregtime edouttime  hospital_expire_flag
# 0                  UNKNOWN       NaT       NaT                     0
# 1                    OTHER       NaT       NaT                     0
# 2                    ASIAN       NaT       NaT                     0
# 3                  UNKNOWN       NaT       NaT                     0
# 4                  UNKNOWN       NaT       NaT                     0
# 5                  UNKNOWN       NaT       NaT                     0
# 6                    WHITE       NaT       NaT                     0
# 7         UNABLE TO OBTAIN       NaT       NaT                     1
# 8                    WHITE       NaT       NaT                     0
# 9                    OTHER       NaT       NaT                     0
# 10                 UNKNOWN       NaT       NaT                     0
# 11                 UNKNOWN       NaT       NaT                     0
# 12                 UNKNOWN       NaT       NaT                     0
# 13                   WHITE       NaT       NaT                     0
# 14                   OTHER       NaT       NaT                     0
# 15                   ASIAN       NaT       NaT                     0
# 16                   WHITE       NaT       NaT                     0
# 17  BLACK/AFRICAN AMERICAN       NaT       NaT                     0
# 18  BLACK/AFRICAN AMERICAN       NaT       NaT                     0
# 19                 UNKNOWN       NaT       NaT                     0

# %%
conn.table("transfers").execute(limit=20)
# Out:
#     subject_id     hadm_id  transfer_id eventtype              careunit  \
# 0     15883097  25063348.0     36143492        ED  Emergency Department
# 1     11911040  23227305.0     37066887        ED  Emergency Department
# 2     15313540  23701153.0     37963493        ED  Emergency Department
# 3     12238614  29387284.0     32928325        ED  Emergency Department
# 4     11222968  25349356.0     37822601        ED  Emergency Department
# 5     17270164  22627031.0     32600471        ED  Emergency Department
# 6     10216527  24501115.0     36542664        ED  Emergency Department
# 7     10645206  20389826.0     31544112        ED  Emergency Department
# 8     19345785  26721665.0     33872320        ED  Emergency Department
# 9     19814293  25844983.0     36185176        ED  Emergency Department
# 10    12644682  20670303.0     36977588        ED  Emergency Department
# 11    14891609  23459292.0     37224925        ED  Emergency Department
# 12    18011469  21223849.0     33679419        ED  Emergency Department
# 13    14947439  24231639.0     38748368        ED  Emergency Department
# 14    15597163  27147811.0     34605310        ED  Emergency Department
# 15    15086965  21295088.0     32158333        ED  Emergency Department
# 16    15447063  23111895.0     35867473        ED  Emergency Department
# 17    19488357         NaN     30905055        ED  Emergency Department
# 18    13500615         NaN     31565210        ED  Emergency Department
# 19    10713361  25928423.0     36480807        ED  Emergency Department
#
#                 intime             outtime
# 0  2156-02-18 12:50:00 2156-02-18 19:25:00
# 1  2181-04-03 11:17:00 2181-04-03 18:03:00
# 2  2116-02-11 23:18:00 2116-02-12 02:20:00
# 3  2116-07-31 13:37:00 2116-07-31 22:08:00
# 4  2176-07-02 10:36:00 2176-07-02 13:49:00
# 5  2144-10-23 20:58:00 2144-10-24 04:07:00
# 6  2157-02-05 07:18:00 2157-02-06 13:00:00
# 7  2151-09-16 14:41:00 2151-09-16 19:20:00
# 8  2185-09-07 14:37:00 2185-09-07 18:32:00
# 9  2181-01-16 19:52:00 2181-01-17 03:06:00
# 10 2158-12-20 06:30:00 2158-12-20 13:12:00
# 11 2178-03-16 18:07:00 2178-03-17 04:17:00
# 12 2191-07-17 16:47:00 2191-07-17 18:55:00
# 13 2146-11-05 18:51:00 2146-11-06 15:36:00
# 14 2144-02-29 04:14:00 2144-02-29 13:34:00
# 15 2129-09-12 17:05:00 2129-09-12 22:57:00
# 16 2186-06-17 16:10:00 2186-06-17 21:13:00
# 17 2182-01-04 16:42:00 2182-01-04 16:57:00
# 18 2174-03-14 15:17:00 2174-03-14 15:35:00
# 19 2148-12-17 18:13:00 2148-12-18 09:28:00

# %% [markdown]
# ### I can connect to another databasae

# %%
conn2 = ibis.bigquery.connect(
    project_id="mimic4-bq",
    dataset_id='physionet-data.mimic_derived',
    credentials=credentials)

# %%
conn2.list_tables()
